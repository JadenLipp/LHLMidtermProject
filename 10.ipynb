# %% [markdown]
# #### **Task 10**: Do bigger delays lead to bigger fuel comsumption per passenger?
# We need to do four things to answer this as accurate as possible:
# - Find out average monthly delay per air carrier (monthly delay is sum of all delays in 1 month)
# - Find out distance covered monthly by different air carriers
# - Find out number of passengers that were carried by different air carriers
# - Find out total fuel comsumption per air carrier.
#
# Use this information to get the average fuel comsumption per passenger per km. Is this higher for the airlines with bigger average delays?

# %% [markdown]
# 1. AA - 1722 | UA - 1738 | DL - 1137 |WN - 1026|B6 - 321|AS - 296|NK - 147|F9 - 134|G4 - 92|HA - 44|VX - 28
# 2.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df1 = pd.read_csv("flight.csv")
df1.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2018-10-26                 AA                 AA          AA
# 1  2018-10-08                 DL       DL_CODESHARE          DL
# 2  2019-09-13                 AS                 AS          AS
# 3  2019-09-22                 UA                 UA          UA
# 4  2019-06-10                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                2199                AA   N916NN               2199
# 1                6290                G7   N376CA               6290
# 2                1302                AS   N283VA               1302
# 3                1175                UA   N775UA               1175
# 4                3460                MQ   N245NN               3460
#
#    origin_airport_id origin   origin_city_name  dest_airport_id dest  \
# 0              15376    TUS         Tucson, AZ            11298  DFW
# ...

# %%
columns = ['fl_date','mkt_carrier','carrier_delay','weather_delay','nas_delay','security_delay','late_aircraft_delay','dep_delay']
df2= df1[columns].dropna()
df2.head()
date = df2['fl_date'].str.split(pat = '-', expand=True)
df2[['Year','Month','Day']] = date
new_col = ['Year','Month','Day','mkt_carrier','carrier_delay','weather_delay','nas_delay','security_delay','late_aircraft_delay','dep_delay']
df3 = df2[new_col]
df4 = df3.loc[df3['mkt_carrier']=='AA']
df5 = df4['Month'].value_counts().mean()
df5
# Out:
# 1722.0833333333333

# %%
def carrier(str):
    df4 = df3.loc[df3['mkt_carrier']==str]
    df5 = df4['Month'].value_counts().mean()
    return df5

# %%
#df3['mkt_carrier'].value_counts()

# %%
carrier('AA')
# Out:
# 1722.0833333333333

# %%
list_carrier = ['AA','UA','DL','WN','B6','AS','NK','F9','G4','HA','VX']

# %%
def all():
    for x in list_carrier:      
        print(carrier(x))

# %%
all()
# Out:
# 1722.0833333333333
# 1378.75
# 1137.4166666666667
# 1026.75
# 321.4166666666667
# 296.0
# 147.66666666666666
# 134.08333333333334
# 92.83333333333333
# 44.583333333333336
# 28.0

# %%
# a = []
# a.append(all())
# b = list_carrier
# res = {a[i]: b[i] for i in range(len(b))}

# %%
column = ['fl_date','mkt_carrier','distance']
df2 = df1[column]
date = df2['fl_date'].str.split(pat = '-', expand=True)
df2[['Year','Month','Day']] = date
newcolumns = ['Month','mkt_carrier','distance']
df3 = df2[newcolumns].dropna()
df3.value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [175], in <cell line: 2>()
#       1 column = ['fl_date','mkt_carrier','distance']
# ----> 2 df2 = df1[column]
#       3 date = df2['fl_date'].str.split(pat = '-', expand=True)
#       4 df2[['Year','Month','Day']] = date
#
# File /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    <a href='file:///usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/frame.py?line=3508'>3509</a>     if is_iterator(key):
#    <a href='file:///usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/pandas/core/frame.py?line=3509'>3510</a>         key = list(key)
# ...

# %%
df1 = pd.read_csv("passenger.csv")
df1.head()
# Out:
#    departures_scheduled  departures_performed    payload   seats  passengers  \
# 0                   0.0                  13.0    16900.0    78.0         3.0
# 1                   0.0                   1.0    28607.0    60.0        48.0
# 2                  17.0                  17.0  3627630.0     0.0         0.0
# 3                   1.0                   1.0    20210.0    79.0        64.0
# 4                  54.0                  54.0  1177362.0  4104.0      3082.0
#
#      freight   mail  distance  ramp_to_ramp  air_time unique_carrier  \
# 0        0.0  562.0      28.0         240.0     188.0             V8
# 1        0.0    0.0     677.0          86.0      76.0            AMQ
# 2  1228229.0    0.0     812.0        2376.0    1992.0            ABX
# 3        0.0    0.0    1031.0         201.0     183.0             YV
# 4        0.0    0.0     931.0        8287.0    6700.0             YX
#
#    airline_id  unique_carrier_name region carrier         carrier_name  \
# ...

# %%
df2
# Out:
# passengers  carrier
# 0.0         FX         16579
#             5X          8904
#             7S          4419
#             DL          3419
#             5Y          2546
#                        ...
# 2414.0      EV             1
#             DL             1
#             BA             1
#             AA             1
# 88925.0     HA             1
# Length: 134916, dtype: int64

# %%
columns = ['passengers','carrier']
df2 = df1[columns]
df2.loc[df2['passengers']==0]
# Out:
#         passengers carrier
# 2              0.0     ABX
# 5              0.0      NC
# 8              0.0      J5
# 11             0.0      5Y
# 14             0.0      5X
# ...            ...     ...
# 399962         0.0      7S
# 399966         0.0     1UQ
# 399970         0.0      YV
# 399989         0.0      7S
# 399991         0.0      FX
#
# [73625 rows x 2 columns]
