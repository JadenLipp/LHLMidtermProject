# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv("flight.csv")
df1.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2018-10-26                 AA                 AA          AA
# 1  2018-10-08                 DL       DL_CODESHARE          DL
# 2  2019-09-13                 AS                 AS          AS
# 3  2019-09-22                 UA                 UA          UA
# 4  2019-06-10                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                2199                AA   N916NN               2199
# 1                6290                G7   N376CA               6290
# 2                1302                AS   N283VA               1302
# 3                1175                UA   N775UA               1175
# 4                3460                MQ   N245NN               3460
#
#    origin_airport_id origin   origin_city_name  dest_airport_id dest  \
# 0              15376    TUS         Tucson, AZ            11298  DFW
# ...

# %% [markdown]
# #### **Task 4**: How taxi times changing during the day? Does higher traffic lead to bigger taxi times?

# %% [markdown]
# 59% of flights occur in the PM, taxi time during PM is on average ~9.85min
# 41% of flights occur in the AM, taxi time during AM is on average ~9.82min
# higher traffic does not necessarily lead to bigger taxi time

# %%
pd.set_option('display.max_columns', None)
df1.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2018-10-26                 AA                 AA          AA
# 1  2018-10-08                 DL       DL_CODESHARE          DL
# 2  2019-09-13                 AS                 AS          AS
# 3  2019-09-22                 UA                 UA          UA
# 4  2019-06-10                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                2199                AA   N916NN               2199
# 1                6290                G7   N376CA               6290
# 2                1302                AS   N283VA               1302
# 3                1175                UA   N775UA               1175
# 4                3460                MQ   N245NN               3460
#
#    origin_airport_id origin   origin_city_name  dest_airport_id dest  \
# 0              15376    TUS         Tucson, AZ            11298  DFW
# ...

# %%
df1['taxi_time'] = df1['taxi_out'] - df1['taxi_in']
df1['Time_Of_Day'] = np.where(df1['dep_time']<= 1200,'AM','PM')
columns = ['taxi_time','dep_time','Time_Of_Day']
df2 = df1[columns]
night_time = df2.loc[df2['Time_Of_Day']=='PM']
night_time.describe()
#day_time = df2.loc[df2['Time_Of_Day']=='AM']
#day_time.describe()

#night_time.shape
#236156/400000
# Out:
#            taxi_time       dep_time
# count  229153.000000  229536.000000
# mean        9.855206    1691.002784
# std        11.927453     305.411419
# min      -172.000000    1201.000000
# 25%         4.000000    1431.000000
# 50%         8.000000    1702.000000
# 75%        14.000000    1934.000000
# max       166.000000    2400.000000

# %%
#taxi in - taxi out -> create new column
#specify certain periods, and specify times i.e. 6am - 10am (Morning)
#focus on departure time -> turn column into 2 categories
#create another new column -> 2 cate
#plot visualize taxi time vs different time period i.e. histogram
#How taxi time changes during the day 
#count higher traffic
