# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv("flight.csv")
pd.set_option('display.max_columns', None)
df1.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2018-10-26                 AA                 AA          AA
# 1  2018-10-08                 DL       DL_CODESHARE          DL
# 2  2019-09-13                 AS                 AS          AS
# 3  2019-09-22                 UA                 UA          UA
# 4  2019-06-10                 AA       AA_CODESHARE          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                2199                AA   N916NN               2199
# 1                6290                G7   N376CA               6290
# 2                1302                AS   N283VA               1302
# 3                1175                UA   N775UA               1175
# 4                3460                MQ   N245NN               3460
#
#    origin_airport_id origin   origin_city_name  dest_airport_id dest  \
# 0              15376    TUS         Tucson, AZ            11298  DFW
# ...

# %% [markdown]
# #### **Task 6**: How many states cover 50% of US air traffic?

# %% [markdown]
# 9 states & Washington D.C.

# %%
columnz = ['origin_city_name','dest_city_name'] 
df2 = df1[columnz]
state = df2['origin_city_name'].str.split(pat = ',', expand=True)
state.columns=['Original_City','Original_State']
# state2 = df2['dest_city_name'].str.split(pat = ',', expand=True)
# state2.columns=['Dest_City','Dest_State']
# result = pd.concat([state,state2],axis=1)
countz = state['Original_State'].value_counts()
countz.shape
countz.sum


     
    

39756+28709+25265+20969+20829+18404+15696+12092+11909+11471
# Out:
# 205100

# %%
countz
# Out:
#  CA    43927
#  TX    39756
#  FL    28709
#  IL    25265
#  GA    20969
#  NY    20829
#  NC    18404
#  CO    15696
#  PA    12092
#  DC    11909
#  WA    11471
#  MI    11204
#  AZ    10268
#  NV     9307
#  OH     9144
#  MN     8456
#  NJ     8434
#  MA     7763
#  MO     7480
#  TN     7107
#  UT     6307
#  HI     5999
#  OR     5717
#  MD     5427
#  LA     4288
#  VA     3893
#  IN     3645
#  WI     3617
#  SC     3514
#  AL     2320
#  OK     2278
#  AK     2153
#  KY     2025
#  ID     1672
#  NM     1652
#  NE     1650
#  AR     1622
#  IA     1578
#  CT     1560
#  MT     1537
#  PR     1490
#  RI     1064
#  ND     1051
#  ME     1035
#  KS      816
#  SD      783
#  MS      777
#  VT      585
#  NH      576
#  WY      520
#  WV      382
#  VI      192
#  TT       85
# Name: Original_State, dtype: int64

# %%
def fifty():
    for c in countz:
        c = c+1
    return c
